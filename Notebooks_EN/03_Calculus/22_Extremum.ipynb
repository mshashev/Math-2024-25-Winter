# %% [markdown]
# 6. The profit function is $P(u) = -2u^2 + 50u - 300$, where $u$ is the number of units sold Find the number of units that maximize profit.
#
# 7. You have 10 meters of string, and you n.eed to use it to enclose the largest possible rectangular. Find the dimensions of the rectangle.
#
# 8. Find extremum od $f(x) = x^2 + 3x - 5$.
#
# 9. Find extremum of $f(x) =\frac{x^2+2x+1}{x-1}$.

# %% [markdown]
# ###6. The profit function is $P(u) = -2u^2 + 50u - 300$, where $u$ is the number of units sold Find the number of units that maximize profit.
#
# As long as we have a quadratic equation we can solve it usind discriminant:
#
# $$-2u^2+50u+300=0|\cdot(-1)$$
#
# $$2u^2-50u-300=0$$
#
# $$D=50^2-4\cdot2\cdot300=2500-2400=100,\quad \sqrt{D}=\sqrt{100}=10$$
#
# $$x_1=\frac{50+10}{2\cdot2}=\frac{60}{4}=15$$
#
# $$x_2=\frac{50-10}{2\cdot2}=\frac{40}{4}=10$$
#
# $u=\frac{15+10}{2}=12.5$
#
# The result $u=12.5$ tells us that the maximum profit occurs when $12.5$ units are sold. However, since the number of units sold must be a whole number, we need to check which nearby whole numbers (12 or 13) give the maximum profit.
#
# $$P(12)=-2(12)^2+50(12)-300=-288+600-300=12$$
#
# $$P(13)=-2(13)^2+50(13)-300=-338+650-300=12$$
#
# ###Conclusion:
# Both $u=12$ and $u=13$ yield the same maximum profit of 12. Therefore, the number of units that muximizes the profit is either 12 or 13 units.

# %% [markdown]
# ###7. You have 10 meters of string, and you need to use it to enclose the largest possible rectangular. Find the dimensions of the rectangle.
#
# We know the perimeter $P=10$ meters, so we have:
#
# Let (a) be length, and (b) be width, then:
#
# $$2a+2b=10 \quad\Rightarrow\quad a+b=5$$
#
# If we want our area being as large as possible, we should get our length and width to be equal to each other.
#
# This is because:
#
# If a is much greater than b, the area is relatively smaller because the width is constrained by the fixed perimeter, leaving the length too long.
# If b is much greater than a, you get a similar issue with the length being too short and the width becoming too large.
#
# So our rectangular will enclose the most space when its demensions will be equal, in other words, when the rectangular becomes square.
#
# We have:
#
# $$a+b=5\quad\Leftrightarrow\quad a+a=5 \quad\Rightarrow\quad 2a=5 \quad\Rightarrow\quad a=2.5 \Rightarrow \begin{cases} a=2.5 \\ b=2.5 \end{cases}$$
#
# Thus, the largest possible rectangle is a square with side lengths of 2.5 meters.

# %% [markdown]
# ###8. Find extremum od $f(x) = x^2 + 3x - 5$.
#
# ###Steps to find extrema:
# - Find the first derivative.
#
# - Set the first derivative equal to zero to find critical points.
#
# - Use the second derivative to determine whether each critical point is a maximum or minimum.
# - Examine endpoints if the function is on a closed interval.
#
# 1)$$f'(x)=\frac{d}{dx}(x^2+3x-5)=2x+3$$
#
# 2)$$2x+3=0\quad\Rightarrow\quad 2x=-3\quad\Rightarrow\quad x=-1.5$$
# so, x=1.5 is a critical point.
#
# 3)$$f''(x)=\frac{d}{dx}(2x+3)=2$$
#
# Since $f''(x)=2$ is positive,this means the function is concave up at x=-1.5. Therefore, x=-1.5 is a local minimum.
#
# 4)$$f(-1.5)=(-1.5)^2+3(-1.5)-5=2.25-4.5-5=-7.25$$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###9. Find extremum of $f(x) =\frac{x^2+2x+1}{x-1}$.
#
# The steps are the same as they were above
#
# 1) $$f'(x)=\frac{g'(x)\cdot h(x)-g(x)\cdot h'(x)}{(h(x))^2}=\frac{(2x+2)\cdot (x-1)-(x^2+2x+1)\cdot1}{(x-1)^2}=\frac{(2x^2-2x+2x-2)-x^2+2x+1}{(x-1)^2}=\frac{x^2-2x-3}{(x-1)^2}$$
#
# 2)$$\frac{x^2-2x-3}{(x-1)^2}=0\quad\Rightarrow\quad \begin{cases} x^2-2x-3=0 \\ (x-1)^2=0 \end{cases}\quad\Rightarrow\quad \begin{cases} x^2-2x-3=0 \\ x=1\end{cases} $$
#
# Let's use Vieta's theorem for both equations: $$ \begin{cases}x_1+x_2=-(-2) \\ x_1\cdot x_2=-3\end{cases} \quad\Rightarrow\quad \begin{cases}x_1+x_2=2 \\ x_1\cdot x_2=-3\end{cases}
#  \qquad \begin{cases}x_1=-1 \\ x_2=3 \\ x_3=1\end{cases}$$this are potencial critical points.
#
# The function is undefined at x=1
#
# 3)Not to get confused with second derivative we could just analyse how the function will behave near the critical points.
#
# ###At x=3:
# - If x is slightly less then 3, the numerator $x^2-2x-3$ is negative, and the denominator $(x-1)^2$ is positive, so the function is nedative.
# - If x is slightly greater then 3, the numerator $x^2-2x-3$ is positive, and the denominator $(x-1)^2$ is also positive, so the function is positive.
#
# ###This means x=3 isa local minimum.
#
# ###At x=-1:
# - If x is slightly less then -1, the numerator $x^2-2x-3$ is poositive, and the denominator $(x-1)^2$ is also positive, so the function is positive.
# - If x is slightly  greater then -1, the numerator $x^2-2x-3$ is negative, and the denominator $(x-1)^2$ is still positive, so the function is negative.
#
# ###This means  x=-1 is a local maximum.
#
#
# ![image.png](data:image/png;base64,...)
