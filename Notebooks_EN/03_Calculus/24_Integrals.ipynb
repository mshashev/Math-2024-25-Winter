# %% [markdown]
# ## Integrals
#
# 1. Compute:
#    - $\int 1 dx$
#    - $\int (x^2 +2) dx$
#    - $\int 2\sin(x) dx$
#    - $\int \frac{3}{x} dx$
#    - $\int \frac{1}{x^2} dx$
#    - $\int \left( \frac{1}{3}x^4 - 5 \right) \, dx$
#    - $\int (\sin^2 x + \cos^2 x) \, dx$
#    - $\int (5 \sin x + 3e^x) \, dx$
#    - $\int \sqrt[3]{x} \, dx$
#    - $\int \sqrt{10x} \, dx$
#    - $\int \cos\left(\frac{5}{2}x + 3\right) \, dx$
#    - $\int \frac{\cos(\ln(x))}{x} \, dx$
#    - $\int x \ln(x) \, dx$
#    - $\int x e^x \, dx$
#
# 2. Calculate integrals over the interval $[0, \pi]$ and visualize them in Geogebra:
#    - $f(x)=2x+1$
#    - $g(x)=x^2$
#
# 3. Calculate the area of the region bounded by the lines:
# $x = 1$, $x = 2$, $y = 0$, and $y = x^2 + 1$. Show it in Geogebra.
#
# 4. Calculate the area under the sine curve over the interval $[0, \pi]$, using:
#
# $$P = \int_a^b f(x) \, dx = \int_0^\pi \sin(x) \, dx$$
#
# 5. Calculate the length of the sine curve over the same interval using:
#
# $$L = \int_a^b \sqrt{1 + (f'(x))^2} \, dx= \int_0^\pi \sqrt{1 + \cos^2(x)} \, dx
# $$
#
# 6. Find the distance of the moving particle between time $t=0$ and $t=2$ for the following position function: $x(t) = 3t^2 - 6t + 1$.

# %% [markdown]
# ###1. Compute:
#
#    - $\int 1 dx=x+C$
#    ---
#    - $\int (x^2 +2) dx=\int x^2 dx +\int 2 dx=\frac{x^3}{3}+2x+C$
#    ---
#    - $\int 2\sin(x) dx=2 \int \sin(x) dx=2\cdot(-\cos(x))+C=-2\cos(x+C)$
#    ---
#    - $\int \frac{3}{x} dx=3 \ln|x|+C$
#    ---
#    - $\int \frac{1}{x^2} dx=\int x^{-2}dx=\frac{x^{-1}}{-1}+C=-x^{-1}+C=\frac-{1}{x}+C$
#    ---
#    - $\int \left( \frac{1}{3}x^4 - 5 \right) \, dx=\frac{x^5}{5\cdot3}-5x+C$
#    ---
#    - $\int (\sin^2 x + \cos^2 x) \, dx-\int 1 \,dx=x+C$
#    ---
#    - $\int (5 \sin x + 3e^x) \, dx=-5\cos+3e^x+C$
#    ---
#    - $\int \sqrt[3]{x} \, dx=\int x^{\frac{1}{3}} \,dx=\frac{x^{\frac{4}{3}}}{\frac{4}{3}}+C=\frac{3}{4}x^{\frac{4}{3}}+C$
#    ---
#    - $\int \sqrt{10x} \, dx=\sqrt{10}\int x^{\frac{1}{2}}\, dx=\sqrt{10}\frac{x^{\frac{3}{2}}}{\frac{3}{2}}+C=\sqrt{10}\cdot\frac{2}{3}x^{\frac{3}{2}}+C$
#    ---
#    - $\int \cos\left(\frac{5}{2}x + 3\right) \, dx= \sin\left(\frac{5}{2}x + 3\right)+C$
#    ---
#    - $\int \frac{\cos(\ln(x))}{x} \, dx\quad if\; u= \ln(x), \; then\; du=\frac{1}{2}dx \quad$ next step, substitute and integrate: $\int \cos(u)du=\sin(u)du+C,\quad$ final step substitute u back: $\sin(\ln(x))+C$
#    ---
#   - Inegration by parts formula:$\int u,dv=uv-\int v\;du$
#
#
# ---
#
#
#    - $\int x \ln(x) \, dx\quad$ We should use integration by parts: if$u-\ln(x),\;and\; dv=x,dx.\;Then\;dv=\frac{1}{2}dx\;and\;v=\frac{x^2}{2}$. Then we have: $\frac{x^2}{2}\ln(x)-\frac{x^2}{4}+C$
#    ---
#    - $\int x e^x \, dx$ $$f(x)=x,\quad f'(x)=1$$ $$g'(x)=e^x,\quad g(x)=e^x$$
#
#    $\int x\cdot e^x\, dx=x\cdot e^x-\int 1\cdot e^x\; dx=x\cdot e^x - e^x$
#
#    Simplify the result: $\int xe^x\;dx=xe^x-e^x+C=e^x(x-1)+C$
#
#
# ---

# %% [markdown]
# ###2. Calculate integrals over the interval  $[0,π]$ and visualize them in Geogebra:
#
#
# ---
#
#
#
# - f(x)=2x+1
#
# $\int_{0}^{\Pi}(2x+1) \, dx=\int_{0}^{\Pi}2x, dx + \int_{0}^{\Pi}1 \, dx$ let's solve them one by one:
#
# $1) \int_{0}^{\Pi}2x\,dx\quad$ (we know that antiderivative of $2x\; is\; x^2$) so let's evaluate it:
# $$x^2\vert_{0}^{\Pi}=\Pi ^2-0^2=\Pi ^2$$
#
# $2)\int_{0}^{\Pi}1 \, dx$ (antiderivative of x is just 1) so:
# $$x\vert_{0}^{\Pi}=\Pi - 0= \Pi$$
#
# Finally, the integral $\int_{0}^{\Pi}(2x+1)$ over interval $[0;\Pi]$ is equal to: $$\Pi ^2 + \Pi$$
#
#
# ---
#
#
# - $g(x)=x^2$
#
# $\int_{0}^{\Pi}x^2\, dx$ (antiderivative of $x^2\;is\;\frac{x^3}{3}$)so:
# $$\frac{x^3}{3}\vert_{0}^{\Pi}=\frac{\Pi ^3}{3}-\frac{0^3}{3}=\frac{\Pi ^3}{3}$$
#
# Finally, the integral $\int_{0}^{\Pi}x^2\, dx$ over interval $[0;\Pi]$ is equal to: $$\frac{\Pi ^3}{3}$$
#
#
# ---

# %% [markdown]
# ###3. Calculate the area of the region bounded by the lines:
# $x = 1$, $x = 2$, $y = 0$, and $y = x^2 + 1$. Show it in Geogebra.
#
# $\int_{1}^{2}x^2+1\;dx=\int x^2\;dx+\int 1\;dx=\frac{x^3}{3}+x$
# $$\left( \frac{x^3}{3}+x\right)_{1}^{2}=\left(\frac{2^3}{3}+2=\frac{8}{3}+2=\frac{8}{3}+\frac{6}{3}=\frac{14}{3}\right)-\left(\frac{1^3}{3}+1=\frac{1}{3}+1=\frac{1}{3}+\frac{3}{3}=\frac{4}{3}\right)=\frac{14}{3}-\frac{4}{3}=\frac{10}{3}$$
#
# The area of the region bounded by the curves is $\frac{10}{3}\approx\;3.33$

# %% [markdown]
# ![image.png](data:image/png;base64,...)
